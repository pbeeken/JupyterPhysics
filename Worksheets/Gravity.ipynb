# %% [markdown]
# # Grabity

# %%
#@title Basic Libraries ++
# First the usual imports:
import numpy as np
# matplotlib is the tool that will create the graphs
import matplotlib.pyplot as plt

#@title Pint (units and uncertainties)
# we need to load two libraries
# !pip install --upgrade pint # handles units with our calculations
#!pip install --upgrade uncertainties # allows us to create numbers with error bars
import pint
SI = pint.UnitRegistry(system="mks")  # loads the default SI units

# %% [markdown]
# ## How far is the moon?

# %% [markdown]
# <img src="https://docs.google.com/drawings/d/1k6bLIi5MmrsJi9POFNbKtzpDW1X4n0Qtp2oSN1EXx3I/export/svg" align="right" width="300px"/>
# Aristarchus of Samos$^1$ around 270 bce came up with a clever idea for determining the distance the moon was from the earth.  Even when sky watchers believed in the Geocentric System the moon was believed to be the closest celestial body to the earth and that it revolved directly around the earth.  All heavenly bodies were assumed to be 'perfect' spheres so given that assumption the shadow cast by the earth on the moon was observed to be a circle roughly the size of the earth.  (Not a bad guesstimate, it is off by about 15%).  If it took about 3.5 hours for Earth's shadow to pass over the moon.  Knowing how long it takes for the moon to orbit the earth, how far away is the moon in terms of the earth's radius. (Hint: draw a circle to represent the moon's orbit and draw a shadow straight back to the moon. Use what you know about speed, distance and the properties of a circle to work out the radius of the orbit.) N.B. the radius of the orbit should be expressed in terms of the radius of the earth.
#
#
# $^1 \scriptsize{
# \text{BTW, he was also the first guy on record to suggest that the earth went around the sun rather than}\\
# \text{ the other way round, mathematically the 'proof' would have to wait almost 600 years until}\\
# \text{ Aryabhata (500CE) came along during the Gupta empire in India. It would take Tycho Brahe (1580)}\\
# \text{ and Johannes Kepler (1620) another 1100 years later to clue into this.}}$

# %% [markdown]
# ## How big is the earth?

# %% [markdown]
# About 30 years later (ca. 240 bce) the radius of the earth was measured by Eratosthenes, the head librarian at Alexandria.  The distance between Alexandria and Syene (N-S) is about 785km. On the summer solstace at noon the light of the sun shines right down to the bottom of a well without casting a shaddow, meaning that it is directly overhead.  At that same time at Alexandria when the sun is perfectly perpendicular at Syene it makes an angle about 7° 12' off the perpendicular rod driven into the ground.  Use this information to determine the radius of the earth.  Once you have size of the earth us the value to determine the distance to the moon in km.
#
# 1) Draw a picture to illustrate this situation... The parallel rays of the sun come down on the curved face of the earth and to to illuminate the bottom of the deep well at Syene. The pole parallel to gravity normal but the pole casts a shaddow that points north.
#
# 2) Estimate the size of the earth using geometry.

# %% [markdown]
# ## Our Friend Galileo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fast forward 1700 years to the Galileo Galilei.  He spots a set of four orbiting bodies about the great celestial orb known as Jupiter.   He modifies an Arabian tool used by sea captains to spot vessels a long way off at sea to look at the sky.  He improves the resolution to the point where he can actually measure the distances of the moons in terms of the radius of Jupiter itself.  He also determines the time it takes for the four little dots to circle Jupiter.  Today these four objects are called the Galilean moons.

# %% [markdown]
# The names and periods of the planets are: Ganymede (7.15days), Callisto (16.69days), Io (1.77days), and Europa (3.55days).  Here are the distances of the moons from Jupiter in terms of Jupiter’s radius:  (inner to outer):  6.0 $r_J$, 9.6 $r_J$, 15.3 $r_J$,  26.9 $r_J$
#
# *At this point you don't have a clue as to what Jupiter's radius is.*
#
# If you suspect that the force acting on each moon is stronger when it is closer, which one do you think is closest to Jupiter and which is farther away?  *hint: if I pull on you more strongly, would you turn faster or slower?*
#
# Enter the correct distance in the following chart:

# %% [markdown]
# |**Moon**|Ganymede|Callisto|Io|Europa|
# |:--|--:|--:|--:|--:|
# |**Period**|7.15days|16.69days|1.77days|3.55days|
# |**Dist from J** [$r_J$]|?|?|?|?|

# %% [markdown]
# Plot the relationship between the period and radius and see what the shape of the curve looks like.
# <font size=-2>*Suggestion: Try making a log-log plot and see what the exponents might be.  Why would this work?  If you think you know this relationship you can go directly to the next step.*</font>
#
# Use your best guess (the exponents should resolve to integers) to see if you can remake the original plot into a straight line.  Remember you are looking for a 'direct' relationship not simply a linear one.
#
# In this kind of graph you need to keep the aspect ratio of the graph as 1. The scaling of the x and y axis need to have the same scale.

# %%
#@title A starting point
radii = np.array([])  # you have to fill this out
period = np.array([])

# we are only looking for the scaling 
# so we "normallize our values"
radii /= np.min(radii)
period /= np.min(period)

# Pick a style
plt.style.use("ggplot")

#plot points
plt.scatter(radii, period)

# use log-log scaling
plt.xscale("log")
plt.yscale("log")
# VERY IMPORTANT: the x and y scale must be the same.
plt.gca().set_aspect(1.0)

# Will probably happen anyway given we "normalized above" but this guarantees it.
plt.xmin(1.0)
plt.ymin(1.0)

plt.show()

# %% [markdown]
# Look at the above graph and see if you can estimate the slope.  Remember that it should be a small integer or a ratio of small integers.
#
# e.g. $\pm 1,\pm 2,\pm 3,\pm \frac{1}{2},\pm \frac{3}{2},\pm \frac{2}{3}, ...$

# %% [markdown]
# ## Along comes Kepler

# %% [markdown]
# Johannes Kepler takes Galileo's idea a bit further. First he and his partner Tycho Brahe collect some painstaking measurements not just on Galilean Moons but planets as well.  Kepler discovers empirically (by experiment) that the relationship you revealed above holds for any orbiting body but the theoretical basis for it will have to wait for Newton.

# %% [markdown]
# ## Our old pal Newton

# %% [markdown]
# Isaac Newton comes along 100 years later and proposes a simple formula for the strength of gravitational pull as a function of distance and the masses of the attracting bodies.
#
# $$F_G = \mathbf{G} \frac{m_1\;m_2}{r^2}$$
#
# The amazing thing about this simple formula is that it made perfect geometrical sense and explained all forms of gravitational attraction from the falling of an apple to the orbit of the moon.  If this is the only force acting on a circularly orbiting body travelling in a circle generates an expression that shows the relationship of the radius of the orbit to the period (time to complete the orbit).
#
# Start by writing an expression that connects the type of an acceleration an object experiences while moving in a circle to the force acting on it.  "What Law was that again?"
#
# *hint: If your going around in a circle what is the time (period) it takes to complete the travel along a circumference?*
#
# Replot your data from above, linearizing the values and use the slope to determine the value for the product of $\mathbf{G}\;m_J$

# %% [markdown]
# ## My man Hyugens

# %% [markdown]
# Just shy of 1700 a mathematician and astronomer Christiaan Huygens figured out a way to measure the diameter of Jupiter and came up with a value that works out to be 10 times the diameter of the earth.  Incidentally he also worked out that the Sun’s diameter  is about 10 times the diameter of Jupiter.
#
# Using the values you got for the moon and earth and the formula you derived from Newton's theories determine the value for $\mathbf{G}\;m_E$.
#
# $$\mathbf{G}\;m_E=...$$
#
# With the previous value you can now compare the mass of Jupiter with the Mass of earth.  See if you can determine the ratio of Jupiters mass to Earth's mass. Don't forget to explain how you got it.
#
# $$m_J / m_E = ... $$
#
# Now that you have the mass ratio try to see if you can come up wiht the ratio of the density of earth to the density of Jupiter?
# $$\frac{\rho_E}{\rho_J}=... $$

# %% [markdown]
# Anything suprising reveal itself with these two values?

# %% [markdown]
# ## Bring it home

# %% [markdown]
# All of this is fun but it would be useful to have a value for $\mathbf{G}$.  It isn’t hard to determine that the average density of rock on the earth crust is about $4.0\;gm/cm^3$. Assume the density of the earth is the same throughout.
#
# Maybe we can determine the value from $\mathbf{g}$?
#
# Consider what the force per unit mass is at the surface of the earth.  Calculate the force on a 100kg object at the surface of the earth using Newton’s formula and by the conventional means we have seen so far.  Plug in the values we have determined so far and see if you can estimate $\mathbf{G}$.  Get a measure of the mass of jupiter as a result.
#
# *hint: don't forget you have $G\;m_J$ above*

# %% [markdown]
# # Auxiliary Questions

# %% [markdown]
# ## Thrid Law

# %% [markdown]
# What is the force between the Earth and the Moon?   The Sun and the Moon?   And the Sun and the Earth? Arrange the calculations in a table with the final column expressed as a ratio of the gravitational force/earth-moon force.
#
# Earth Mass: $1\;m_⊕ = ...kg$
#
# Moon Mass: $1\;m_☾ = ...kg$
#
# Solar Mass: $1\;m_☉ = ...kg$

# %% [markdown]
# ## Tidal Law

# %% [markdown]
# Anyone who has spent any time at the shore has experienced the effects of the tides as the water rises and falls.  Based on the results in the problem can you explain why the tides are mostly blamed on the moon?  Let's look at a different perspective: what is the difference in the force of gravity on $1000 kg$ of material on the far side of the earth vs on the near side of the Earth  from the pull of the Moon?   Do the same calculation with the Sun on a $1000 kg$ of material on the near and far side of the Earth.  What is the ratio of the differences?  How much influence (relatively) do you think the sun vs the moon have on the tides?
#
# *hint: See if you can come up with a simple way to calculate the difference in gravitational force from one side of an object from the other.*
#
# Earth Radius:  1r⊕=...kg
