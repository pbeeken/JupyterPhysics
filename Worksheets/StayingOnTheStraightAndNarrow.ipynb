# %% [markdown]
# # Some more tradtional exercises
# Here is a problem set that mirrors more traditional exercises to relate to our kinematic examples.  I present them in Jupyter so you have a calculator right near where you will report on your findings.

# %% [markdown]
# ## Imports

# %%
#@title Usual imports
# First the usual imports:
import numpy as np
# matplotlib is the tool that will create the graphs
import matplotlib.pyplot as plt

# %%
#@title Optional imports
# we need to load two libraries
# !pip install --upgrade pint # handles units with our calculations
import pint
SI = pint.UnitRegistry(system="mks")  # loads the default SI units

# %%
#@title Test the pint environment (Only if you want it)
distance = 3.4 * SI.meters # just a test
timer = 1.23 * SI.minute
speed = distance/timer
print(f"avg speed: {speed.to_base_units():6.3P}")
# Out:
# avg speed: 0.0461 meter/second

# %% [markdown]
# ## Moving Right Along

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quick takes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Build a model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   Runs leftward $-$ is left $+$ is right
#   1. $x = 1.2 \cdot t$
#   3. $x = - a_1 \cdot \frac{1}{2} t^2$
#   3. $x = + a_2 \cdot \frac{1}{2} t^2$
#   3. $x = - a_3 \cdot \frac{1}{2} t^2$
#
# I think this is better done by tracking the velocity
#
#   1. $v_1 = -1.2$
#   2. $v_2 = 1.2 - a_1 t$ but stop when $v = -0.6$
#   3. $v_3 = 0.6 + a_2 t$
#   4. $v_4 = 2.0 - a_3 t$

# %%
def mouseVel(t):
  # returns velocity in m/s
  a = 1 # meter per second^2
  if t<10.0:
    vel = -1.2
  elif t>10.0 and t<20.0:  # t has to be such that v_f = -0.6 m/s
    vel = -1.2 + a * t
  elif t>20.0 and t<30.0:
    pass
  else


## Put all your plotting stuff down here.

# %% [markdown]
# ## Bang the rocks

# %% [markdown]
# ![image.png](data:image/png;base64,...)
