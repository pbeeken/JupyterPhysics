# %% [markdown]
# # Up and Over

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A small block of mass $2\;m$ initially rests on a track at the bottom of the circular, vertical loop-the-loop shown above, which has a radius $r$. The surtace contact between the block and the loop is frictionless, A bullet of mass m strikes the block horizontally with initial speed and remains embedded in the block as the block and bullet circle the loop, Determine each the following in terms of $m$, $v_0$, $r$, and $g$

# %% [markdown]
# ## A. The speed of the block and bullet immediately after impact.
#
# Be sure to outline how you might solve this problem before you start assembling expressions.

# %% [markdown]
# ## B. The kinetic energy of the block and bullet when they reach point P on the loop.
#
# What considerations do you now have to add to solve this part of the interaction.

# %% [markdown]
# ## C. The minimum initial speed of the bullet if the block and bullet are to successfully execute a complete circuit of the loop.
#
# Be sure to diagram what you may need to consider to keep the block on the track as it passes inside the loop at the top of the loop.

# %% [markdown]
# # Piled Higher and Deeper

# %% [markdown]
# A $3000\;kg$ block falls vertically through $6.0\;m$ and then collides with a $500\;kg$ pile, driving it $3.0\;cm$ into bedrock. Assuming that the block—pile collision is completely inelastic, find the magnitude of the average force on the pile from the bedrock during the $3.0\;cm$ descent.

# %% [markdown]
# What are the physical principals you need to apply to solve this problem?
#   -
#   -
#   -

# %% [markdown]
# # Travelin' Along

# %% [markdown]
# <img src="data:image/png;base64,..." align="right"/>
# A remote-controlled toy car of mass 2.0 kg starts from rest at the origin at t=0 and moves in the positive direction of an x axis. The net force on the car as a function of time is given by the figure on the right.
#
#   - What is the time rate of change of the momentum of the car at t = 3.0s?
#   - What is the momentum of the car at t = 3.0 s?

# %% [markdown]
# ## Turbine Power

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d9/Peltonturbine-1.jpg" align="left" width="150px"/><img src="data:image/png;base64,..." align="right"/>
# A stream of water strikes a stationary "dished" turbine blade typical of one found in a hydroelectric plant.  These blades are arranged on around the circumference of a wheel where jets of water are aimed at the curved blades in the manner illustrated at the right. The speed of the water is $v$, both before and after the interaction with the blade.  The mass flow of the water is $\frac{\mathbb{d}}{\mathbb{dt}}m$ which remains constant.  What is the force on the blade from the water?
#
#
# This is a 'figure this out' type problem.  Look at the dimensions of force, momentum and mass flow.  How can you assemble an expression that dimensionally, at least, makes all the values work out.

# %% [markdown]
# # Exploding Fireworks

# %% [markdown]
# A new experimental two stage firework is launched on a ballistic trajectory where a timed fuse will explosively split the firework into two parts just past its peak about 5/9 of the total time in the air.  The shell leaves the ground at $60. m/s$ at an angle of $85^o$ from the horizontal.  At the time of the seperation one piece with half the mass of the other piece is launched $20^o$from the vertical down at the ground with a speed of $20. m/s$ relative to the motion of the original projectile.  If all goes according to plan how high does the second stage rise before releasing its amazing pyrotechnics? (*assume all this action happens in a single x-y plane*)
#
# Some hints:
#   - See if you can sketch a graph of the firework's trajectory.
#   - What are the key points in the fireworks motion?
#   - What physical principals apply and at what stage?

# %% [markdown]
# # Loss of Energy

# %% [markdown]
# In an elastic collision we know that all the energy conserved in the interaction is preserved in kinetic energy.  This represents a coefficient of restitution, $e$, of 1.  An inelastic collision, on the other hand, has a value for $e$=0. The definition is the ratio of the relative velocity after the collision divided by the relative velocity before the collision:
# $$e = \frac{\left|\text{rel velocity After}\right|}{\left|\text{rel velocity Before}\right|}$$
#
# What would the ratio of total kinetic energy for purely inelastic collision between an object of mass $m_1$ and $m_2$ where the first mass with an initial velocity of $v$ collides with the second, initially at rest?
